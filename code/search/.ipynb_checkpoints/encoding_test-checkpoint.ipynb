# %%
# %load_ext autoreload
# %autoreload 2
import os
import torch
from glob import glob
import sys
from PIL import Image
import pandas as pd

# %%
# %pwd
# Out:
# '/home/taindp/computer_vision/image_retrieval/code/search'

# %%
# sys.path

# %%
if not '/home/taindp/computer_vision/image_retrieval/code/siamese_net' in sys.path:
    sys.path.append('/home/taindp/computer_vision/image_retrieval/code/siamese_net')

# %%
from model_class import *
from custom_transforms import transform_test
from custom_dataloader import EncodeDataFactory
import torch
from encode_pipeline import *
# Out:
# /home/taindp/anaconda3/envs/vision/lib/python3.6/site-packages/torchvision/transforms/transforms.py:1322: UserWarning: Argument interpolation should be of type InterpolationMode instead of int. Please, use InterpolationMode enum.
#   "Argument interpolation should be of type InterpolationMode instead of int. "
# cpu

# %%
_MODEL_PATH = '../../model'
_IMG_PATH = '../../data/meta_data'
_RESOURCE_PATH = '../../resource'

# %%
best_model = glob(os.path.join(_MODEL_PATH,'*'))[-1] 
# load_model = torch.load(best_model,map_location=torch.device('cpu'))

# %%
def load_checkpoint(filepath):
    checkpoint = torch.load(filepath, map_location = {'cuda:0':'cpu'})
    model = checkpoint['model']
    model.load_state_dict(checkpoint['model_state_dict'])
    for parameter in model.parameters():
        parameter.requires_grad = False
    model.eval()
    return model

# %%
load_model = load_checkpoint(best_model)

# %% [markdown]
# ## Encoding 1 image

# %%
test_img = sorted(glob(os.path.join('../../test/image','*.jpg')))[1]
# test_img = '../../data/meta_data/11494375/2.jpg'
test_tensor = transform_test(Image.open(test_img))
test_tensor = test_tensor.unsqueeze(0)

# %%
Image.open(test_img)
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=640x640 at 0x7FC9C855FA90>

# %%
test_enc = load_model(test_tensor).squeeze(0)

# %%
torch.save(test_enc,'../../test/encode/test_enc.h5')
