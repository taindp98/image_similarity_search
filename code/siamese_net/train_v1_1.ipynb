# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import zipfile

# %%
# %cd '/content/drive/MyDrive/image_retrieval/data/'
with zipfile.ZipFile('meta_data.zip', 'r') as zip_ref:
    zip_ref.extractall('/content/drive/MyDrive/image_retrieval/data')
# Out:
# /content/drive/.shortcut-targets-by-id/12kTq--EdJ7TtMqRmQngfJGL2k8ZYpSG4/image_retrieval/data

# %%
# %cd meta_data
# !ls

# %%
# %cd '/content/drive/MyDrive/image_retrieval/code/siamese_net'
# Out:
# /content/drive/MyDrive/image_retrieval/code/siamese_net

# %%
# %load_ext autoreload
# %autoreload 2
from custom_dataloader import TripletDataFactory
import torch
from train_pipeline import *
from model_class import RecommendNet
from triplet_loss import TripletLoss
# Out:
# /usr/local/lib/python3.7/dist-packages/torchvision/transforms/transforms.py:1322: UserWarning: Argument interpolation should be of type InterpolationMode instead of int. Please, use InterpolationMode enum.
#   "Argument interpolation should be of type InterpolationMode instead of int. "
# cuda:0

# %% [markdown]
# ## Training

# %%
model = RecommendNet()
# model
model.cuda()
# Out:
# RecommendNet(
#   (net): ResNet(
#     (conv1): Conv2d(3, 64, kernel_size=(7, 7), stride=(2, 2), padding=(3, 3), bias=False)
#     (bn1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (relu): ReLU(inplace=True)
#     (maxpool): MaxPool2d(kernel_size=3, stride=2, padding=1, dilation=1, ceil_mode=False)
#     (layer1): Sequential(
#       (0): Bottleneck(
#         (conv1): Conv2d(64, 64, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (conv2): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (bn2): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (conv3): Conv2d(64, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn3): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu): ReLU(inplace=True)
# ...

# %%
loss = TripletLoss(alpha = .7, device = device)

# %%
init_lr = 5e-4
weight_decay = 0.0001
step_size = 5
gamma = 0.5
epochs = 200
seed = 0

# %%
opt = torch.optim.Adam(model.parameters(), lr = init_lr, weight_decay=weight_decay)
scheduler = torch.optim.lr_scheduler.StepLR(opt, step_size=int(step_size), gamma= gamma, last_epoch=-1)

# %%
train(model, epochs, loss_fn = loss, optimize = opt, scheduler = scheduler, seed = 0, verbose=True)
# Out:
# Output hidden; open in https://colab.research.google.com to view.
